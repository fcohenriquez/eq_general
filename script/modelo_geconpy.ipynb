# %% [markdown]
# # Modelo gEconpy para Equilibrio General Dinámico

# %%
import numpy as np
import preliz as pz

import gEconpy as ge
import gEconpy.plotting as gp

seed = sum(map(ord, "Intro to gEconpy"))
rng = np.random.default_rng(seed)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 4
#       1 import numpy as np
#       2 import preliz as pz
# ----> 4 import gEconpy as ge
#       5 import gEconpy.plotting as gp
#       7 seed = sum(map(ord, "Intro to gEconpy"))
#
# File c:\Users\francisco.henriquez\AppData\Local\Programs\Python\Python311\Lib\site-packages\gEconpy\__init__.py:6
#       2 import sys
#       4 from importlib.metadata import version
# ----> 6 from gEconpy import (
#       7     classes,
#       8     numbaf,  #  noqa: F401
#       9     parser,
#      10     plotting,
#      11     solvers,
#      12     utilities,
#      13 )
#      14 from gEconpy.dynare_convert import make_mod_file
#      15 from gEconpy.model.build import model_from_gcn, statespace_from_gcn
#
# File c:\Users\francisco.henriquez\AppData\Local\Programs\Python\Python311\Lib\site-packages\gEconpy\plotting.py:20
# ...
